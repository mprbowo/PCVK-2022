# %% [markdown]
# <a href="https://colab.research.google.com/github/mprbowo/PCVK-2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import  cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/ImagesPCVK/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/ImagesPCVK/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/ImagesPCVK/mandrill2.tiff',img5)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
cv.circle(black_img,center=(400,400),radius=1,color=(255,0,0),thickness=100)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
cv.circle(black_img,center=(400,400),radius=1,color=(255,0,0),thickness=100)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
img_5 = img.copy()
img_6 = img.copy()
img_5[:,:,2] = 0 
img_6[:,:,0] = 0 


final_frame = cv.hconcat((img_5, img_6))
plt.imshow(final_frame)

# %%
img_7 = img[10:100, 10:100]

plt.imshow(img_7)

# %%
img_8 = img[5:30]

plt.imshow(img_8)

# %%
img_9 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_9, pt1=(230,100), pt2=(410,200), color=(0,0,255), thickness=10)
cv.rectangle(img_9, pt1=(300,200), pt2=(210,100), color=(255,0,255), thickness=10)
cv.rectangle(img_9, pt1=(100,150), pt2=(500,400), color=(0,255,255), thickness=10)
cv.rectangle(img_9, pt1=(250,50), pt2=(50,100), color=(0,255,0), thickness=10)
cv.rectangle(img_9, pt1=(330,400), pt2=(300,150), color=(255,255,255), thickness=10)

plt.imshow(img_9)

# %%
img_10 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)


plt.imshow(img_10)

# %%
img_12 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_12, pt1=(250,50), pt2=(500,250), color=(255,255,255), thickness=10)
cv.circle(img_12, center=(400,150), radius=100, color=(255,255,255), thickness=10)

plt.imshow(img_12)

# %%
img_11 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_11, pt1=(100,600), pt2=(0,500), color=(255,255,255), thickness=10)

plt.imshow(img_11)
